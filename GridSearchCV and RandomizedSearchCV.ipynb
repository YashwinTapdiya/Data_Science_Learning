# %%
# importing the dependencies
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
# loading the data from sklearn
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
# loading the data to a data frame
data_frame = pd.DataFrame(breast_cancer_dataset.data, columns = breast_cancer_dataset.feature_names)

# %%
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# adding the 'target' column to the data frame
data_frame['label'] = breast_cancer_dataset.target

# %%
# print the first 5 rows of the dataframe
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
# number of rows and Columns in this dataset
data_frame.shape
# Out:
# (569, 31)

# %%
# checking for missing values
data_frame.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
# checking the distribution of Target Varibale
data_frame['label'].value_counts()
# Out:
# 1    357
# 0    212
# Name: label, dtype: int64

# %%
X = data_frame.drop(columns='label', axis=1)
Y = data_frame['label']

# %%
X = np.asarray(X)
Y = np.asarray(Y)

# %% [markdown]
# # **GridSearchCV**

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters:

parameters = {
    'kernel': ["linear" , "poly" ,"rbf","sigmoid"],
    'C' : [1,5,10,20]
}

# %%
# grid search
classifier = GridSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([2.27286029e+00, 3.11980247e-03, 4.52222824e-03, 1.14285946e-02,
#         4.26781044e+00, 2.79908180e-03, 3.90710831e-03, 1.85842991e-02,
#         5.98195167e+00, 5.41024208e-03, 9.80997086e-03, 2.23002911e-02,
#         1.10192403e+01, 8.50582123e-03, 8.17427635e-03, 2.20906258e-02]),
#  'std_fit_time': array([5.61389821e-01, 3.75911379e-04, 3.24023414e-04, 1.29014934e-03,
#         1.29443476e+00, 3.99376367e-04, 4.98087228e-04, 7.68172668e-03,
#         1.50501740e+00, 1.11740637e-03, 2.02802711e-03, 2.73696866e-03,
#         3.67882320e+00, 1.45741596e-03, 1.32642125e-03, 3.06117047e-03]),
#  'mean_score_time': array([0.00130544, 0.00099788, 0.00230107, 0.00312042, 0.00120606,
#         0.00130181, 0.00200419, 0.00490222, 0.00139928, 0.00166993,
#         0.00498991, 0.00588121, 0.00165138, 0.00191073, 0.00349603,
#         0.00601068]),
#  'std_score_time': array([8.77563372e-04, 1.42732902e-06, 4.01819121e-04, 2.09750525e-04,
#         3.98936045e-04, 4.00578673e-04, 3.15634771e-04, 2.16238926e-03,
#         4.89785185e-04, 8.45377461e-04, 6.15577997e-04, 7.40753236e-04,
#         7.67392657e-04, 6.61658928e-04, 5.75431281e-04, 6.18695149e-04]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 ]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 ]),
#  'rank_test_score': array([ 4, 12, 11, 13,  2,  6,  5, 14,  1,  8,  7, 15,  3, 10,  9, 16])}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the resukts to pandas dataframe:

result =pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       2.272860      0.561390         0.001305        0.000878       1
# 1       0.003120      0.000376         0.000998        0.000001       1
# 2       0.004522      0.000324         0.002301        0.000402       1
# 3       0.011429      0.001290         0.003120        0.000210       1
# 4       4.267810      1.294435         0.001206        0.000399       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.885965           0.929825           0.947368           0.938053
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.929825           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                4
# 1         0.908663        0.039382               12
# 2         0.912172        0.035444               11
# 3         0.460441        0.050253               13
# 4         0.950815        0.016216                2

# %%
grid_search_result = result[["param_C" , "param_kernel" ,"mean_test_score"]]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10, 'kernel':'linear'}

# %% [markdown]
# # RandomizedSearchCV

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = RandomizedSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([9.12690163e-03, 1.29190922e-02, 3.91440392e-03, 3.00617218e-03,
#         2.20854774e+00, 8.87622833e-03, 2.58511066e-02, 1.16328045e+01,
#         3.91855240e-03, 3.81159782e-03]),
#  'std_fit_time': array([1.03274207e-03, 1.88640948e-03, 3.78505467e-04, 3.24691772e-04,
#         9.69862944e-01, 9.61150318e-04, 1.70007018e-03, 3.93590290e+00,
#         3.92784247e-04, 5.12905917e-04]),
#  'mean_score_time': array([0.00433006, 0.00321746, 0.00100083, 0.00120173, 0.00160022,
#         0.00240374, 0.00694227, 0.00153451, 0.00099983, 0.00210238]),
#  'std_score_time': array([1.02480334e-03, 2.56067725e-04, 6.97552626e-07, 4.00854330e-04,
#         8.00466601e-04, 3.74943246e-04, 8.11787232e-04, 6.87918863e-04,
#         1.50487269e-06, 2.04926171e-04]),
#  'param_kernel': masked_array(data=['rbf', 'sigmoid', 'poly', 'poly', 'linear', 'poly',
#                     'sigmoid', 'linear', 'poly', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_C': masked_array(data=[20, 5, 10, 1, 1, 5, 1, 20, 20, 5],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'kernel': 'rbf', 'C': 20},
#   {'kernel': 'sigmoid', 'C': 5},
#   {'kernel': 'poly', 'C': 10},
#   {'kernel': 'poly', 'C': 1},
#   {'kernel': 'linear', 'C': 1},
#   {'kernel': 'poly', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 1},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'poly', 'C': 20},
#   {'kernel': 'rbf', 'C': 5}],
#  'split0_test_score': array([0.87719298, 0.49122807, 0.88596491, 0.84210526, 0.94736842,
#         0.88596491, 0.54385965, 0.92982456, 0.87719298, 0.88596491]),
#  'split1_test_score': array([0.92105263, 0.42105263, 0.92105263, 0.88596491, 0.92982456,
#         0.9122807 , 0.45614035, 0.95614035, 0.92105263, 0.92982456]),
#  'split2_test_score': array([0.92105263, 0.42105263, 0.90350877, 0.92982456, 0.97368421,
#         0.92105263, 0.46491228, 0.95614035, 0.90350877, 0.93859649]),
#  'split3_test_score': array([0.94736842, 0.35087719, 0.93859649, 0.94736842, 0.92105263,
#         0.93859649, 0.38596491, 0.93859649, 0.93859649, 0.94736842]),
#  'split4_test_score': array([0.9380531 , 0.37168142, 0.95575221, 0.9380531 , 0.95575221,
#         0.95575221, 0.45132743, 0.96460177, 0.95575221, 0.95575221]),
#  'mean_test_score': array([0.92094395, 0.41117839, 0.920975  , 0.90866325, 0.94553641,
#         0.92272939, 0.46044093, 0.9490607 , 0.91922062, 0.93150132]),
#  'std_test_score': array([0.02410455, 0.04857818, 0.02470123, 0.03938232, 0.01868869,
#         0.02368918, 0.05025317, 0.01281637, 0.02730027, 0.02435811]),
#  'rank_test_score': array([ 6, 10,  5,  8,  2,  4,  9,  1,  7,  3])}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 20}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9490607048594939

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.009127      0.001033         0.004330    1.024803e-03          rbf
# 1       0.012919      0.001886         0.003217    2.560677e-04      sigmoid
# 2       0.003914      0.000379         0.001001    6.975526e-07         poly
# 3       0.003006      0.000325         0.001202    4.008543e-04         poly
# 4       2.208548      0.969863         0.001600    8.004666e-04       linear
#
#   param_C                         params  split0_test_score  \
# 0      20     {'kernel': 'rbf', 'C': 20}           0.877193
# 1       5  {'kernel': 'sigmoid', 'C': 5}           0.491228
# 2      10    {'kernel': 'poly', 'C': 10}           0.885965
# 3       1     {'kernel': 'poly', 'C': 1}           0.842105
# 4       1   {'kernel': 'linear', 'C': 1}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.921053           0.921053           0.947368           0.938053
# 1           0.421053           0.421053           0.350877           0.371681
# 2           0.921053           0.903509           0.938596           0.955752
# 3           0.885965           0.929825           0.947368           0.938053
# 4           0.929825           0.973684           0.921053           0.955752
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.920944        0.024105                6
# 1         0.411178        0.048578               10
# 2         0.920975        0.024701                5
# 3         0.908663        0.039382                8
# 4         0.945536        0.018689                2

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0      20          rbf         0.920944
# 1       5      sigmoid         0.411178
# 2      10         poly         0.920975
# 3       1         poly         0.908663
# 4       1       linear         0.945536
# 5       5         poly         0.922729
# 6       1      sigmoid         0.460441
# 7      20       linear         0.949061
# 8      20         poly         0.919221
# 9       5          rbf         0.931501
